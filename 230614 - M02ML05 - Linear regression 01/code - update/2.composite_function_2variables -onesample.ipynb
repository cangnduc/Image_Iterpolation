# %% [markdown]
# ### Optimization

# %%
import random

# predict function
def predicted_func(x, a, b):
    return a*x + b

# parameters
num_steps = 100
lr = 0.01

# given data 
x1 = -2
y1 = -1

x2 = 5
y2 = 13

# 1. set a, b randomly
a = random.random()*10.0 - 5.0
b = random.random()*10.0 - 5.0
print(a, b)

for i in range(num_steps):
    # -------- for the first point ----------
    x_value, y_value = x1, y1
    
    # compute predicted_y
    predicted_y = predicted_func(x_value, a, b)
    
    # compute g
    g_value = (predicted_y - y_value)**2
    
    # compute partial gradients for a and b
    dg_da = 2*x_value*(predicted_y - y_value) 
    dg_db = 2*(predicted_y - y_value) 
    
    # update
    a = a - lr*dg_da 
    b = b - lr*dg_db
    
     # print
    if i%10==0:
        print(f'a: {a} and b: {b}')
        print(f'g_value 1: {g_value}')
        print('-------------')
    
    
    # -------- for the second point ----------
    x_value, y_value = x2, y2
    
    # compute predicted_y
    predicted_y = predicted_func(x_value, a, b)
    
    # compute g
    g_value = (predicted_y - y_value)**2
    
    # compute partial gradients for a and b
    dg_da = 2*x_value*(predicted_y - y_value) 
    dg_db = 2*(predicted_y - y_value) 
    
    # update
    a = a - lr*dg_da 
    b = b - lr*dg_db
    
    
    # print
    if i%10==0:
        print(f'a: {a} and b: {b}')
        print(f'g_value 2: {g_value}')
        print('-------------')
# Out:
# -2.297455356038949 1.12155925282197
# a: -2.028796557442954 and b: 0.9872298535239726
# g_value 1: 45.11096878940203
# -------------
# a: 0.18687873592612592 and b: 1.4303649121977886
# g_value 2: 490.9217005646157
# -------------
# a: 2.0979574654063984 and b: 2.043342250966251
# g_value 1: 1.6400293608995657
# -------------
# a: 2.144644507606574 and b: 2.052679659406286
# g_value 2: 0.21796799094009803
# -------------
# a: 2.0691865276726453 and b: 2.3336833977306823
# g_value 1: 0.7994141297184142
# -------------
# a: 2.1012249240632546 and b: 2.3400910770088044
# g_value 2: 0.10264588432817916
# -------------
# a: 2.048199518070235 and b: 2.5358065714594282
# g_value 1: 0.3879801376014391
# -------------
# a: 2.070519101889175 and b: 2.540270488223216
# g_value 2: 0.049816382185067704
# -------------
# a: 2.0335784847696954 and b: 2.676616851215651
# g_value 1: 0.18829825187693947
# -------------
# a: 2.0491275572632826 and b: 2.6797266657143686
# g_value 2: 0.02417736554108346
# -------------
# a: 2.023392653728209 and b: 2.774713180987047
# g_value 1: 0.09138671852045152
# -------------
# a: 2.0342250087653997 and b: 2.776879651994485
# g_value 2: 0.011733991565175
# -------------
# a: 2.016296633162584 and b: 2.8430525801614293
# g_value 1: 0.044352681125210895
# -------------
# a: 2.023843058565149 and b: 2.844561865241942
# g_value 2: 0.005694853635647906
# -------------
# a: 2.0113531476813837 and b: 2.8906616343472433
# g_value 1: 0.021525669756425503
# -------------
# a: 2.0166104104059674 and b: 2.89171308689216
# g_value 2: 0.002763881135529921
# -------------
# a: 2.007909238735964 and b: 2.923828768794592
# g_value 1: 0.010447045064865688
# -------------
# a: 2.011571742488523 and b: 2.9245612695451038
# g_value 2: 0.0013413933737507853
# -------------
# a: 2.0055100188192787 and b: 2.946934852842285
# g_value 1: 0.005070260383175853
# -------------
# a: 2.0080615241254107 and b: 2.9474451539035114
# g_value 2: 0.0006510179327220296
# -------------

# %%
import numpy as np
import matplotlib.pyplot as plt

# f function
def blackbox_func(x):
    return 2*x + 3

def func1(x):
    return 2.008*x + 2.947

# plot f_func
x_list = np.arange(-10, 10, 0.1).tolist()
fx_list = [blackbox_func(x) for x in x_list]
fx1_list = [func1(x) for x in x_list]

plt.plot(x_list, fx_list, 'r')
plt.plot(x_list, fx1_list, 'g')
plt.show()

# %% [markdown]
# ### Using list

# %%
import random

# predict function
def predicted_func(x, a, b):
    return a*x + b

# parameters
num_steps = 100
lr = 0.01

# given data 
data = [[-2, -1],
        [5, 13]]

# 1. set a, b randomly
a = random.random()*10.0 - 5.0
b = random.random()*10.0 - 5.0
print(a, b)

for i in range(num_steps):
    for sample in data:
        x_value, y_value = sample

        # compute predicted_y
        predicted_y = predicted_func(x_value, a, b)

        # compute g
        g_value = (predicted_y - y_value)**2

        # compute partial gradients for a and b
        dg_da = 2*x_value*(predicted_y - y_value) 
        dg_db = 2*(predicted_y - y_value) 

        # update
        a = a - lr*dg_da 
        b = b - lr*dg_db

         # print
        if i%10==0:
            print(f'a: {a} and b: {b}')
            print(f'g_value: {g_value}')
            print('-------------')
# Out:
# -0.4983387793532863 2.825474407606192
# a: -0.3054527007007757 and b: 2.7290313682799368
# g_value: 23.253149586214064
# -------------
# a: 0.8743705128216184 and b: 2.9649960109844153
# g_value: 139.19828151663089
# -------------
# a: 1.9933671652459524 and b: 3.0565756389084298
# g_value: 0.006021985631274283
# -------------
# a: 1.9910260187321331 and b: 3.0561074096056657
# g_value: 0.0005480966999167913
# -------------
# a: 1.9958989480294063 and b: 3.0394934858756426
# g_value: 0.0028084806024386492
# -------------
# a: 1.994000125427139 and b: 3.0391137213551893
# g_value: 0.0003605527274881087
# -------------
# a: 1.9971431463299831 and b: 3.02751340079421
# g_value: 0.00136301322835152
# -------------
# a: 1.9958202330855708 and b: 3.0272488181453276
# g_value: 0.0001750099452241755
# -------------
# a: 1.9980097557328669 and b: 3.0191673764424007
# g_value: 0.0006615106826889117
# -------------
# a: 1.9970881402221934 and b: 3.018983053340266
# g_value: 8.493751495139582e-05
# -------------
# a: 1.99861348433992 and b: 3.0133530682837555
# g_value: 0.00032105072646346704
# -------------
# a: 1.9979714353415843 and b: 3.0132246584840883
# g_value: 4.1222691626368785e-05
# -------------
# a: 1.999034075511525 and b: 3.0093024954733063
# g_value: 0.00015581542620618044
# -------------
# a: 1.9985867882084318 and b: 3.0092130380126876
# g_value: 2.000659315082909e-05
# -------------
# a: 1.9993270828853225 and b: 3.0064806395198445
# g_value: 7.562184116902487e-05
# -------------
# a: 1.9990154774906768 and b: 3.0064183184409154
# g_value: 9.709792197227327e-06
# -------------
# a: 1.9995312082376742 and b: 3.0045147765679316
# g_value: 3.670151923357131e-05
# -------------
# a: 1.9993141264620438 and b: 3.0044713602128055
# g_value: 4.712449731080924e-06
# -------------
# a: 1.9996734133942635 and b: 3.003145246297981
# g_value: 1.7812334283701616e-05
# -------------
# a: 1.9995221820673337 and b: 3.003115000032595
# g_value: 2.2870914244961956e-06
# -------------

# %%
import numpy as np
import matplotlib.pyplot as plt

# f function
def blackbox_func(x):
    return 2*x + 3

def func1(x):
    return 1.999*x + 3.003

# plot f_func
x_list = np.arange(-10, 10, 0.1).tolist()
fx_list = [blackbox_func(x) for x in x_list]
fx1_list = [func1(x) for x in x_list]

plt.plot(x_list, fx_list, 'r')
plt.plot(x_list, fx1_list, 'g')
plt.show()
